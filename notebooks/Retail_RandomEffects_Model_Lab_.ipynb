# %% [markdown]
# # Retail Lab (Random Effects Model)

# %% [markdown]
# **Learning Objectives:**
#   * Define and fit random effects regression models
#   * Gain exposure to retail related DataSets

# %% [markdown]
# ## Context of the datasets
#
# ### 1. There are three datasets: `articles.csv.zip`, `customers.csv.zip` and `transactions2020.csv.zip`
#
# #### 2. The Articles dataset contains information over products available.
# #### 3. The Customers dataset contains information over registered customers.
# #### 4. The Transactions dataset contains purchases of articles made by customers.

# %% [markdown]
# ## 1. Library Import

# %%
# !pip install linearmodels
# Out:
# Collecting linearmodels
#   Downloading linearmodels-6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from linearmodels) (1.26.4)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from linearmodels) (2.1.4)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from linearmodels) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from linearmodels) (0.14.2)
# Collecting mypy-extensions>=0.4 (from linearmodels)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.10/dist-packages (from linearmodels) (3.0.11)
# Collecting pyhdfe>=0.1 (from linearmodels)
#   Downloading pyhdfe-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting formulaic>=1.0.0 (from linearmodels)
#   Downloading formulaic-1.0.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting setuptools-scm<9.0.0,>=8.0.0 (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels)
#   Downloading setuptools_scm-8.1.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.0.0->linearmodels)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=1.0.0->linearmodels) (4.12.2)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=1.0.0->linearmodels) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->linearmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->linearmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->linearmodels) (2024.1)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (24.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (71.0.4)
# Requirement already satisfied: tomli>=1 in /usr/local/lib/python3.10/dist-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (2.0.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.0->linearmodels) (0.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.13.0->linearmodels) (1.16.0)
# Downloading linearmodels-6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 26.8 MB/s eta 0:00:00
# Downloading formulaic-1.0.2-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.5/94.5 kB 6.9 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pyhdfe-0.2.0-py3-none-any.whl (19 kB)
# Downloading setuptools_scm-8.1.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.7 MB/s eta 0:00:00
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Installing collected packages: setuptools-scm, mypy-extensions, interface-meta, pyhdfe, formulaic, linearmodels
# Successfully installed formulaic-1.0.2 interface-meta-1.3.0 linearmodels-6.0 mypy-extensions-1.0.0 pyhdfe-0.2.0 setuptools-scm-8.1.0

# %%
import pandas as pd
import warnings
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf
from matplotlib import pyplot as plt
import scipy.stats as stats
import linearmodels as plm

# %%
warnings.simplefilter('ignore')

# %% [markdown]
# ## 2. Data loading and DataFrame creation

# %%
Articles=pd.read_csv("https://github.com/thousandoaks/Python4DS-I/raw/main/datasets/articles.csv.zip")

# %%
Articles.head(3)
# Out:
#    article_id  product_code      prod_name  product_type_no product_type_name  \
# 0   108775015        108775      Strap top              253          Vest top
# 1   108775044        108775      Strap top              253          Vest top
# 2   108775051        108775  Strap top (1)              253          Vest top
#
#    product_group_name  graphical_appearance_no graphical_appearance_name  \
# 0  Garment Upper body                  1010016                     Solid
# 1  Garment Upper body                  1010016                     Solid
# 2  Garment Upper body                  1010017                    Stripe
#
#    colour_group_code colour_group_name  ...  department_name index_code  \
# 0                  9             Black  ...     Jersey Basic          A
# 1                 10             White  ...     Jersey Basic          A
# 2                 11         Off White  ...     Jersey Basic          A
#
#    index_name index_group_no  index_group_name section_no  \
# 0  Ladieswear              1        Ladieswear         16
# 1  Ladieswear              1        Ladieswear         16
# 2  Ladieswear              1        Ladieswear         16
#
#              section_name garment_group_no  garment_group_name  \
# 0  Womens Everyday Basics             1002        Jersey Basic
# 1  Womens Everyday Basics             1002        Jersey Basic
# 2  Womens Everyday Basics             1002        Jersey Basic
#
#                                detail_desc
# 0  Jersey top with narrow shoulder straps.
# 1  Jersey top with narrow shoulder straps.
# 2  Jersey top with narrow shoulder straps.
#
# [3 rows x 25 columns]

# %%
Articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105542 entries, 0 to 105541
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   article_id                    105542 non-null  int64
#  1   product_code                  105542 non-null  int64
#  2   prod_name                     105542 non-null  object
#  3   product_type_no               105542 non-null  int64
#  4   product_type_name             105542 non-null  object
#  5   product_group_name            105542 non-null  object
#  6   graphical_appearance_no       105542 non-null  int64
#  7   graphical_appearance_name     105542 non-null  object
#  8   colour_group_code             105542 non-null  int64
#  9   colour_group_name             105542 non-null  object
#  10  perceived_colour_value_id     105542 non-null  int64
#  11  perceived_colour_value_name   105542 non-null  object
#  12  perceived_colour_master_id    105542 non-null  int64
#  13  perceived_colour_master_name  105542 non-null  object
#  14  department_no                 105542 non-null  int64
#  15  department_name               105542 non-null  object
#  16  index_code                    105542 non-null  object
#  17  index_name                    105542 non-null  object
#  18  index_group_no                105542 non-null  int64
#  19  index_group_name              105542 non-null  object
#  20  section_no                    105542 non-null  int64
#  21  section_name                  105542 non-null  object
#  22  garment_group_no              105542 non-null  int64
#  23  garment_group_name            105542 non-null  object
#  24  detail_desc                   105126 non-null  object
# dtypes: int64(11), object(14)
# memory usage: 20.1+ MB

# %%
Customers=pd.read_csv("https://github.com/thousandoaks/Python4DS-I/raw/main/datasets/customers.csv.zip")

# %%
Customers.sample(3)
# Out:
#                                               customer_id   FN  Active  \
# 21749   041601fe23123b9d1a43ed431ac5f1fdf045bf5eb9cda8...  NaN     NaN
# 661778  7b88403dc81e720f9b0ec0f530ecf329a1d021e9f066cf...  1.0     1.0
# 917659  ab38ec9858511142bcf3cc9abcc653faf8e003b0011186...  NaN     NaN
#
#        club_member_status fashion_news_frequency   age  \
# 21749              ACTIVE                   NONE  20.0
# 661778             ACTIVE              Regularly  31.0
# 917659         PRE-CREATE                   NONE  21.0
#
#                                               postal_code
# 21749   2c29ae653a9282cce4151bd87643c907644e09541abc28...
# 661778  19f4f36844d3cc61056b8c5b3ff1edfd221ac8fdeb6c00...
# 917659  ea6911567a34fd7e6055fcc9ccbd9a83964b6a2741249f...

# %%
Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1371980 entries, 0 to 1371979
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   customer_id             1371980 non-null  object
#  1   FN                      476930 non-null   float64
#  2   Active                  464404 non-null   float64
#  3   club_member_status      1365918 non-null  object
#  4   fashion_news_frequency  1355969 non-null  object
#  5   age                     1356119 non-null  float64
#  6   postal_code             1371980 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 73.3+ MB

# %%
Transactions=pd.read_csv("https://github.com/thousandoaks/Python4DS-I/raw/main/datasets/transactions2020.csv.zip")

# %%
Transactions.sample(3)
# Out:
#               t_dat                                        customer_id  \
# 4936061  2020-09-16  ecbe914acaf164501d65eed0ef2b12c77178f9b2a7ec09...
# 4456164  2020-09-03  cb231027792a0d40955a3512b0d39d0fa3e0ad6c6c2624...
# 3017704  2020-07-29  d577a533b28c147095df33479bdc8be453e10ababd0f36...
#
#          article_id     price  sales_channel_id
# 4936061   894956006  0.023034                 1
# 4456164   783707147  0.003542                 1
# 3017704   537732002  0.025407                 1

# %%
Transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5151470 entries, 0 to 5151469
# Data columns (total 5 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   t_dat             object
#  1   customer_id       object
#  2   article_id        int64
#  3   price             float64
#  4   sales_channel_id  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 196.5+ MB

# %% [markdown]
# ## 3. Merging DataFrames

# %% [markdown]
# #### 3.1. Transactions-Articles

# %%
Transactions.head(3)
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2020-06-01  00075ef36696a7b4ed8c83e22a4bf7ea7c90ee110991ec...   844198001
# 1  2020-06-01  000b31552d3785c79833262bbeefa484cbc43d7b612b3c...   777016001
# 2  2020-06-01  002d8d26c9414c981c012c6f5e4b2de7ffd3bc568c4574...   820507001
#
#       price  sales_channel_id
# 0  0.016932                 2
# 1  0.030492                 1
# 2  0.010153                 2

# %%
Articles.head(3)
# Out:
#    article_id  product_code      prod_name  product_type_no product_type_name  \
# 0   108775015        108775      Strap top              253          Vest top
# 1   108775044        108775      Strap top              253          Vest top
# 2   108775051        108775  Strap top (1)              253          Vest top
#
#    product_group_name  graphical_appearance_no graphical_appearance_name  \
# 0  Garment Upper body                  1010016                     Solid
# 1  Garment Upper body                  1010016                     Solid
# 2  Garment Upper body                  1010017                    Stripe
#
#    colour_group_code colour_group_name  ...  department_name index_code  \
# 0                  9             Black  ...     Jersey Basic          A
# 1                 10             White  ...     Jersey Basic          A
# 2                 11         Off White  ...     Jersey Basic          A
#
#    index_name index_group_no  index_group_name section_no  \
# 0  Ladieswear              1        Ladieswear         16
# 1  Ladieswear              1        Ladieswear         16
# 2  Ladieswear              1        Ladieswear         16
#
#              section_name garment_group_no  garment_group_name  \
# 0  Womens Everyday Basics             1002        Jersey Basic
# 1  Womens Everyday Basics             1002        Jersey Basic
# 2  Womens Everyday Basics             1002        Jersey Basic
#
#                                detail_desc
# 0  Jersey top with narrow shoulder straps.
# 1  Jersey top with narrow shoulder straps.
# 2  Jersey top with narrow shoulder straps.
#
# [3 rows x 25 columns]

# %%
## we merge both DataFrames using the common key: article_id. We store the result in a new DataFrame
TransactionsAndArticles=pd.merge(Transactions, Articles, how='left',on='article_id')

# %% [markdown]
# #### 3.2. Transactions-Articles-Customers

# %%
TransactionsAndArticles.head(3)
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2020-06-01  00075ef36696a7b4ed8c83e22a4bf7ea7c90ee110991ec...   844198001
# 1  2020-06-01  000b31552d3785c79833262bbeefa484cbc43d7b612b3c...   777016001
# 2  2020-06-01  002d8d26c9414c981c012c6f5e4b2de7ffd3bc568c4574...   820507001
#
#       price  sales_channel_id  product_code                  prod_name  \
# 0  0.016932                 2        844198             Saturn trs (J)
# 1  0.030492                 1        777016                Cisco skirt
# 2  0.010153                 2        820507  Charlotte Hipster Primula
#
#    product_type_no product_type_name  product_group_name  ...  \
# 0              296     Pyjama bottom           Nightwear  ...
# 1              275             Skirt  Garment Lower body  ...
# 2              286  Underwear bottom           Underwear  ...
#
#        department_name index_code        index_name index_group_no  \
# 0            Nightwear          B  Lingeries/Tights              1
# 1     Trousers & Skirt          A        Ladieswear              1
# 2  Expressive Lingerie          B  Lingeries/Tights              1
#
#    index_group_name section_no                    section_name  \
# 0        Ladieswear         62  Womens Nightwear, Socks & Tigh
# 1        Ladieswear         18                    Womens Trend
# 2        Ladieswear         61                 Womens Lingerie
#
#   garment_group_no  garment_group_name  \
# 0             1017   Under-, Nightwear
# 1             1009            Trousers
# 2             1017   Under-, Nightwear
#
#                                          detail_desc
# 0  Pyjama bottoms in sweatshirt fabric with wide ...
# 1  Calf-length skirt in softly draping, patterned...
# 2  Hipster briefs in lace with a mid waist, lined...
#
# [3 rows x 29 columns]

# %%
Customers.head(3)
# Out:
#                                          customer_id  FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3... NaN     NaN
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e... NaN     NaN
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca... NaN     NaN
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  49.0
# 1             ACTIVE                   NONE  25.0
# 2             ACTIVE                   NONE  24.0
#
#                                          postal_code
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...

# %%
## we merge both DataFrames using the common key: customer_id. We store the result in a new DataFrame
TransactionsAndArticlesAndCustomers=pd.merge(TransactionsAndArticles, Customers, how='left',on='customer_id')

# %% [markdown]
# ## 4. Exploratory Data Analysis

# %%
TransactionsAndArticlesAndCustomers.head(3)
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2020-06-01  00075ef36696a7b4ed8c83e22a4bf7ea7c90ee110991ec...   844198001
# 1  2020-06-01  000b31552d3785c79833262bbeefa484cbc43d7b612b3c...   777016001
# 2  2020-06-01  002d8d26c9414c981c012c6f5e4b2de7ffd3bc568c4574...   820507001
#
#       price  sales_channel_id  product_code                  prod_name  \
# 0  0.016932                 2        844198             Saturn trs (J)
# 1  0.030492                 1        777016                Cisco skirt
# 2  0.010153                 2        820507  Charlotte Hipster Primula
#
#    product_type_no product_type_name  product_group_name  ...  \
# 0              296     Pyjama bottom           Nightwear  ...
# 1              275             Skirt  Garment Lower body  ...
# 2              286  Underwear bottom           Underwear  ...
#
#                      section_name garment_group_no  garment_group_name  \
# 0  Womens Nightwear, Socks & Tigh             1017   Under-, Nightwear
# 1                    Womens Trend             1009            Trousers
# 2                 Womens Lingerie             1017   Under-, Nightwear
#
#                                          detail_desc   FN Active  \
# 0  Pyjama bottoms in sweatshirt fabric with wide ...  NaN    NaN
# 1  Calf-length skirt in softly draping, patterned...  1.0    1.0
# 2  Hipster briefs in lace with a mid waist, lined...  NaN    NaN
#
#    club_member_status fashion_news_frequency   age  \
# 0              ACTIVE                   NONE  40.0
# 1              ACTIVE              Regularly  59.0
# 2              ACTIVE                   NONE  23.0
#
#                                          postal_code
# 0  0c0e15f8fa88a1d4aa6ca8a0b4a8289ca1affbaebdea22...
# 1  2c29ae653a9282cce4151bd87643c907644e09541abc28...
# 2  8d4ceb946237cf52ce5c2a1a71d1221fde77627a52d661...
#
# [3 rows x 35 columns]

# %%
TransactionsAndArticlesAndCustomers.sample(3).T
# Out:
#                                                                         4020712  \
# t_dat                                                                2020-08-23
# customer_id                   c3238aa349bd40e5e5c2afd501afd665969c617f94dc04...
# article_id                                                            372860072
# price                                                                  0.013542
# sales_channel_id                                                              2
# product_code                                                             372860
# prod_name                                                    Basic 7p Shaftless
# product_type_no                                                             302
# product_type_name                                                         Socks
# product_group_name                                               Socks & Tights
# graphical_appearance_no                                                 1010010
# graphical_appearance_name                                               Melange
# colour_group_code                                                            52
# colour_group_name                                                          Pink
# perceived_colour_value_id                                                     2
# perceived_colour_value_name                                        Medium Dusty
# perceived_colour_master_id                                                    4
# perceived_colour_master_name                                               Pink
# department_no                                                              3611
# department_name                                                Shopbasket Socks
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   62
# section_name                                     Womens Nightwear, Socks & Tigh
# garment_group_no                                                           1021
# garment_group_name                                             Socks and Tights
# detail_desc                     Fine-knit trainer socks in a soft cotton blend.
# FN                                                                          NaN
# Active                                                                      NaN
# club_member_status                                                       ACTIVE
# fashion_news_frequency                                                     NONE
# age                                                                        27.0
# postal_code                   ffbd8d09bb275ee75807ec0c8fa6eef2202b20a8e89453...
#
#                                                                         2720095  \
# t_dat                                                                2020-07-22
# customer_id                   e647c40d8c0ab5915b59cf50ce2d6ae1205d82935ca2a3...
# article_id                                                            784001005
# price                                                                  0.022017
# sales_channel_id                                                              2
# product_code                                                             784001
# prod_name                                                                Rocky!
# product_type_no                                                             258
# product_type_name                                                        Blouse
# product_group_name                                           Garment Upper body
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                            10
# colour_group_name                                                         White
# perceived_colour_value_id                                                     3
# perceived_colour_value_name                                               Light
# perceived_colour_master_id                                                    9
# perceived_colour_master_name                                              White
# department_no                                                              1515
# department_name                                                          Blouse
# index_code                                                                    A
# index_name                                                           Ladieswear
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   11
# section_name                                                   Womens Tailoring
# garment_group_no                                                           1010
# garment_group_name                                                      Blouses
# detail_desc                   Sleeveless blouse in woven fabric with a V-nec...
# FN                                                                          NaN
# Active                                                                      NaN
# club_member_status                                                       ACTIVE
# fashion_news_frequency                                                     NONE
# age                                                                        54.0
# postal_code                   3bfaab4f15cc6de9e3c7a0ec36603ae2dfa42754d981eb...
#
#                                                                         2494838
# t_dat                                                                2020-07-17
# customer_id                   385860ff039c2eb314699ac5d844ca7df4d0ab0f1dd86f...
# article_id                                                            492897001
# price                                                                  0.025407
# sales_channel_id                                                              2
# product_code                                                             492897
# prod_name                                              Alba Push-Up Biker HW FS
# product_type_no                                                             286
# product_type_name                                              Underwear bottom
# product_group_name                                                    Underwear
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                             9
# colour_group_name                                                         Black
# perceived_colour_value_id                                                     4
# perceived_colour_value_name                                                Dark
# perceived_colour_master_id                                                    5
# perceived_colour_master_name                                              Black
# department_no                                                              3710
# department_name                                             Functional Lingerie
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   61
# section_name                                                    Womens Lingerie
# garment_group_no                                                           1017
# garment_group_name                                            Under-, Nightwear
# detail_desc                   Bikers in jersey with a firm shaping effect on...
# FN                                                                          1.0
# Active                                                                      1.0
# club_member_status                                                       ACTIVE
# fashion_news_frequency                                                Regularly
# age                                                                        25.0
# postal_code                   05d8c5b11d4215507b675da10eae94a9341e3a80e7060e...

# %%
TransactionsAndArticlesAndCustomers['t_dat']=pd.to_datetime(TransactionsAndArticlesAndCustomers['t_dat'])

# %%
TransactionsAndArticlesAndCustomers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5151470 entries, 0 to 5151469
# Data columns (total 35 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   t_dat                         datetime64[ns]
#  1   customer_id                   object
#  2   article_id                    int64
#  3   price                         float64
#  4   sales_channel_id              int64
#  5   product_code                  int64
#  6   prod_name                     object
#  7   product_type_no               int64
#  8   product_type_name             object
#  9   product_group_name            object
#  10  graphical_appearance_no       int64
#  11  graphical_appearance_name     object
#  12  colour_group_code             int64
#  13  colour_group_name             object
#  14  perceived_colour_value_id     int64
#  15  perceived_colour_value_name   object
#  16  perceived_colour_master_id    int64
#  17  perceived_colour_master_name  object
#  18  department_no                 int64
#  19  department_name               object
#  20  index_code                    object
#  21  index_name                    object
#  22  index_group_no                int64
#  23  index_group_name              object
#  24  section_no                    int64
#  25  section_name                  object
#  26  garment_group_no              int64
#  27  garment_group_name            object
#  28  detail_desc                   object
#  29  FN                            float64
#  30  Active                        float64
#  31  club_member_status            object
#  32  fashion_news_frequency        object
#  33  age                           float64
#  34  postal_code                   object
# dtypes: datetime64[ns](1), float64(4), int64(12), object(18)
# memory usage: 1.3+ GB

# %%
del Articles, Customers, Transactions

# %%
TransactionsAndArticlesAndCustomers.groupby('t_dat').count()
# Out:
#             customer_id  article_id  price  sales_channel_id  product_code  \
# t_dat
# 2020-06-01        43084       43084  43084             43084         43084
# 2020-06-02        44666       44666  44666             44666         44666
# 2020-06-03        53187       53187  53187             53187         53187
# 2020-06-04        50470       50470  50470             50470         50470
# 2020-06-05        44470       44470  44470             44470         44470
# ...                 ...         ...    ...               ...           ...
# 2020-09-18        39284       39284  39284             39284         39284
# 2020-09-19        36796       36796  36796             36796         36796
# 2020-09-20        31489       31489  31489             31489         31489
# 2020-09-21        32130       32130  32130             32130         32130
# 2020-09-22        32866       32866  32866             32866         32866
#
#             prod_name  product_type_no  product_type_name  product_group_name  \
# t_dat
# 2020-06-01      43084            43084              43084               43084
# 2020-06-02      44666            44666              44666               44666
# 2020-06-03      53187            53187              53187               53187
# 2020-06-04      50470            50470              50470               50470
# 2020-06-05      44470            44470              44470               44470
# ...               ...              ...                ...                 ...
# 2020-09-18      39284            39284              39284               39284
# 2020-09-19      36796            36796              36796               36796
# 2020-09-20      31489            31489              31489               31489
# 2020-09-21      32130            32130              32130               32130
# 2020-09-22      32866            32866              32866               32866
#
#             graphical_appearance_no  ...  section_name  garment_group_no  \
# t_dat                                ...
# 2020-06-01                    43084  ...         43084             43084
# 2020-06-02                    44666  ...         44666             44666
# 2020-06-03                    53187  ...         53187             53187
# 2020-06-04                    50470  ...         50470             50470
# 2020-06-05                    44470  ...         44470             44470
# ...                             ...  ...           ...               ...
# 2020-09-18                    39284  ...         39284             39284
# 2020-09-19                    36796  ...         36796             36796
# 2020-09-20                    31489  ...         31489             31489
# 2020-09-21                    32130  ...         32130             32130
# 2020-09-22                    32866  ...         32866             32866
#
#             garment_group_name  detail_desc     FN  Active  \
# t_dat
# 2020-06-01               43084        43050  19110   18855
# 2020-06-02               44666        44626  18863   18659
# 2020-06-03               53187        53122  23647   23291
# 2020-06-04               50470        50427  22440   22159
# 2020-06-05               44470        44415  19500   19258
# ...                        ...          ...    ...     ...
# 2020-09-18               39284        39275  17958   17679
# 2020-09-19               36796        36790  15418   15188
# 2020-09-20               31489        31482  13799   13502
# 2020-09-21               32130        32124  14145   13949
# 2020-09-22               32866        32858  13989   13757
#
#             club_member_status  fashion_news_frequency    age  postal_code
# t_dat
# 2020-06-01               43030                   42986  42950        43084
# 2020-06-02               44607                   44543  44529        44666
# 2020-06-03               53124                   53003  52933        53187
# 2020-06-04               50344                   50334  50294        50470
# 2020-06-05               44426                   44347  44332        44470
# ...                        ...                     ...    ...          ...
# 2020-09-18               39235                   39211  39168        39284
# 2020-09-19               36725                   36701  36626        36796
# 2020-09-20               31415                   31408  31375        31489
# 2020-09-21               32067                   32072  32033        32130
# 2020-09-22               32826                   32807  32734        32866
#
# [114 rows x 34 columns]

# %%
TransactionsAndArticlesAndCustomers.groupby('sales_channel_id').count()
# Out:
#                     t_dat  customer_id  article_id    price  product_code  \
# sales_channel_id
# 1                 1788396      1788396     1788396  1788396       1788396
# 2                 3363074      3363074     3363074  3363074       3363074
#
#                   prod_name  product_type_no  product_type_name  \
# sales_channel_id
# 1                   1788396          1788396            1788396
# 2                   3363074          3363074            3363074
#
#                   product_group_name  graphical_appearance_no  ...  \
# sales_channel_id                                               ...
# 1                            1788396                  1788396  ...
# 2                            3363074                  3363074  ...
#
#                   section_name  garment_group_no  garment_group_name  \
# sales_channel_id
# 1                      1788396           1788396             1788396
# 2                      3363074           3363074             3363074
#
#                   detail_desc       FN   Active  club_member_status  \
# sales_channel_id
# 1                     1786791   817650   804129             1787640
# 2                     3361065  1502625  1482103             3356625
#
#                   fashion_news_frequency      age  postal_code
# sales_channel_id
# 1                                1780039  1779148      1788396
# 2                                3358923  3352518      3363074
#
# [2 rows x 34 columns]

# %%
TransactionsAndArticlesAndCustomers.groupby('department_name').count()
# Out:
#                         t_dat  customer_id  article_id  price  \
# department_name
# AK Bottoms               4400         4400        4400   4400
# AK Dresses & Outdoor     2879         2879        2879   2879
# AK Other                  113          113         113    113
# AK Tops Jersey & Woven    390          390         390    390
# AK Tops Knitwear          392          392         392    392
# ...                       ...          ...         ...    ...
# Young Girl Shoes          380          380         380    380
# Young Girl Swimwear       699          699         699    699
# Young Girl Trouser        952          952         952    952
# Young Girl UW/NW         1554         1554        1554   1554
# Young boy Swimwear        350          350         350    350
#
#                         sales_channel_id  product_code  prod_name  \
# department_name
# AK Bottoms                          4400          4400       4400
# AK Dresses & Outdoor                2879          2879       2879
# AK Other                             113           113        113
# AK Tops Jersey & Woven               390           390        390
# AK Tops Knitwear                     392           392        392
# ...                                  ...           ...        ...
# Young Girl Shoes                     380           380        380
# Young Girl Swimwear                  699           699        699
# Young Girl Trouser                   952           952        952
# Young Girl UW/NW                    1554          1554       1554
# Young boy Swimwear                   350           350        350
#
#                         product_type_no  product_type_name  \
# department_name
# AK Bottoms                         4400               4400
# AK Dresses & Outdoor               2879               2879
# AK Other                            113                113
# AK Tops Jersey & Woven              390                390
# AK Tops Knitwear                    392                392
# ...                                 ...                ...
# Young Girl Shoes                    380                380
# Young Girl Swimwear                 699                699
# Young Girl Trouser                  952                952
# Young Girl UW/NW                   1554               1554
# Young boy Swimwear                  350                350
#
#                         product_group_name  ...  section_name  \
# department_name                             ...
# AK Bottoms                            4400  ...          4400
# AK Dresses & Outdoor                  2879  ...          2879
# AK Other                               113  ...           113
# AK Tops Jersey & Woven                 390  ...           390
# AK Tops Knitwear                       392  ...           392
# ...                                    ...  ...           ...
# Young Girl Shoes                       380  ...           380
# Young Girl Swimwear                    699  ...           699
# Young Girl Trouser                     952  ...           952
# Young Girl UW/NW                      1554  ...          1554
# Young boy Swimwear                     350  ...           350
#
#                         garment_group_no  garment_group_name  detail_desc  \
# department_name
# AK Bottoms                          4400                4400         4400
# AK Dresses & Outdoor                2879                2879         2879
# AK Other                             113                 113          113
# AK Tops Jersey & Woven               390                 390          390
# AK Tops Knitwear                     392                 392          392
# ...                                  ...                 ...          ...
# Young Girl Shoes                     380                 380          380
# Young Girl Swimwear                  699                 699          699
# Young Girl Trouser                   952                 952          952
# LEFT CLUB               559          559         559      559
# PRE-CREATE            61265        61265       61265    61265
#
#                     sales_channel_id  product_code  prod_name  \
# club_member_status
# ACTIVE                       5082441       5082441    5082441
# LEFT CLUB                        559           559        559
# PRE-CREATE                     61265         61265      61265
#
#                     product_type_no  product_type_name  product_group_name  \
# club_member_status
# ACTIVE                      5082441            5082441             5082441
# LEFT CLUB                       559                559                 559
# PRE-CREATE                    61265              61265               61265
#
#                     ...  section_no  section_name  garment_group_no  \
# club_member_status  ...
# ACTIVE              ...     5082441       5082441           5082441
# LEFT CLUB           ...         559           559               559
# PRE-CREATE          ...       61265         61265             61265
#
#                     garment_group_name  detail_desc       FN   Active  \
# club_member_status
# ACTIVE                         5082441      5078877  2315032  2281184
# LEFT CLUB                          559          559        0        0
# PRE-CREATE                       61265        61217     4518     4325
#
#                     fashion_news_frequency      age  postal_code
# club_member_status
# ACTIVE                             5071449  5067537      5082441
# LEFT CLUB                              559      559          559
# PRE-CREATE                           60629    57269        61265
#
# [3 rows x 34 columns]

# %%
TransactionsAndArticlesAndCustomers.groupby('fashion_news_frequency').count()
# Out:
#                           t_dat  customer_id  article_id    price  \
# fashion_news_frequency
# Monthly                     954          954         954      954
# NONE                    2811991      2811991     2811991  2811991
# Regularly               2326017      2326017     2326017  2326017
#
#                         sales_channel_id  product_code  prod_name  \
# fashion_news_frequency
# Monthly                              954           954        954
# NONE                             2811991       2811991    2811991
# Regularly                        2326017       2326017    2326017
#
#                         product_type_no  product_type_name  \
# fashion_news_frequency
# Monthly                             954                954
# NONE                            2811991            2811991
# Regularly                       2326017            2326017
#
#                         product_group_name  ...  section_no  section_name  \
# fashion_news_frequency                      ...
# Monthly                                954  ...         954           954
# NONE                               2811991  ...     2811991       2811991
# Regularly                          2326017  ...     2326017       2326017
#
#                         garment_group_no  garment_group_name  detail_desc  \
# fashion_news_frequency
# Monthly                              954                 954          953
# NONE                             2811991             2811991      2809906
# Regularly                        2326017             2326017      2324499
#
#                              FN   Active  club_member_status      age  \
# fashion_news_frequency
# Monthly                     947      926                 954      952
# NONE                       1212      814             2806374  2797394
# Regularly               2318116  2284492             2325309  2321747
#
#                         postal_code
# fashion_news_frequency
# Monthly                         954
# NONE                        2811991
# Regularly                   2326017
#
# [3 rows x 34 columns]

# %% [markdown]
# ## 5. Evolution of sales accross time and sales channels (Random Effects Model)
# ### We are interested in determining the temporal evolution of sales accross the two different sales channels. To do this we fit a random effects model regressing `CustomerSales` on several factors.

# %% [markdown]
# #### We need to compute the volume of purchases made by each department first

# %%
TransactionsAndArticlesAndCustomers[['t_dat','customer_id','article_id','price','sales_channel_id','department_name']]
# Out:
#              t_dat                                        customer_id  \
# 0       2020-06-01  00075ef36696a7b4ed8c83e22a4bf7ea7c90ee110991ec...
# 1       2020-06-01  000b31552d3785c79833262bbeefa484cbc43d7b612b3c...
# 2       2020-06-01  002d8d26c9414c981c012c6f5e4b2de7ffd3bc568c4574...
# 3       2020-06-01  002d8d26c9414c981c012c6f5e4b2de7ffd3bc568c4574...
# 4       2020-06-01  002d8d26c9414c981c012c6f5e4b2de7ffd3bc568c4574...
# ...            ...                                                ...
# 5151465 2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 5151466 2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 5151467 2020-09-22  fff380805474b287b05cb2a7507b9a013482f7dd0bce0e...
# 5151468 2020-09-22  fff4d3a8b1f3b60af93e78c30a7cb4cf75edaf2590d3e5...
# 5151469 2020-09-22  fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...
#
#          article_id     price  sales_channel_id      department_name
# 0         844198001  0.016932                 2            Nightwear
# 1         777016001  0.030492                 1     Trousers & Skirt
# 2         820507001  0.010153                 2  Expressive Lingerie
# 3         869811005  0.016932                 2               Jersey
# 4         823118004  0.025407                 2             Swimwear
# ...             ...       ...               ...                  ...
# 5151465   929511001  0.059305                 2              Dresses
# 5151466   891322004  0.042356                 2              Dresses
# 5151467   918325001  0.043203                 1                 Bags
# 5151468   833459002  0.006763                 1            Jewellery
# 5151469   898573003  0.033881                 2               Blouse
#
# [5151470 rows x 6 columns]

# %%
SalesPerDepartment=TransactionsAndArticlesAndCustomers.groupby(['department_name','t_dat','sales_channel_id']).agg({'price':'sum'}).reset_index()
SalesPerDepartment.rename(columns={'price':'salesperdepartment'},inplace=True)
SalesPerDepartment
# Out:
#           department_name      t_dat  sales_channel_id  salesperdepartment
# 0              AK Bottoms 2020-06-01                 2            0.613203
# 1              AK Bottoms 2020-06-02                 2            0.533763
# 2              AK Bottoms 2020-06-03                 1            0.042356
# 3              AK Bottoms 2020-06-03                 2            0.842407
# 4              AK Bottoms 2020-06-04                 1            0.088932
# ...                   ...        ...               ...                 ...
# 41205  Young boy Swimwear 2020-08-30                 1            0.010153
# 41206  Young boy Swimwear 2020-09-01                 1            0.011847
# 41207  Young boy Swimwear 2020-09-02                 1            0.015237
# 41208  Young boy Swimwear 2020-09-07                 1            0.015237
# 41209  Young boy Swimwear 2020-09-19                 2            0.010153
#
# [41210 rows x 4 columns]

# %%
## We extract the month in which the transaction took place

SalesPerDepartment['month']=SalesPerDepartment['t_dat'].dt.month
SalesPerDepartment
# Out:
#           department_name      t_dat  sales_channel_id  salesperdepartment  \
# 0              AK Bottoms 2020-06-01                 2            0.613203
# 1              AK Bottoms 2020-06-02                 2            0.533763
# 2              AK Bottoms 2020-06-03                 1            0.042356
# 3              AK Bottoms 2020-06-03                 2            0.842407
# 4              AK Bottoms 2020-06-04                 1            0.088932
# ...                   ...        ...               ...                 ...
# 41205  Young boy Swimwear 2020-08-30                 1            0.010153
# 41206  Young boy Swimwear 2020-09-01                 1            0.011847
# 41207  Young boy Swimwear 2020-09-02                 1            0.015237
# 41208  Young boy Swimwear 2020-09-07                 1            0.015237
# 41209  Young boy Swimwear 2020-09-19                 2            0.010153
#
#        month
# 0          6
# 1          6
# 2          6
# 3          6
# 4          6
# ...      ...
# 41205      8
# 41206      9
# 41207      9
# 41208      9
# 41209      9
#
# [41210 rows x 5 columns]

# %%
SalesPerDepartment.set_index(['department_name', 'month'], drop=False,inplace=True)
SalesPerDepartment
# Out:
#                              department_name      t_dat  sales_channel_id  \
# department_name    month
# AK Bottoms         6              AK Bottoms 2020-06-01                 2
#                    6              AK Bottoms 2020-06-02                 2
#                    6              AK Bottoms 2020-06-03                 1
#                    6              AK Bottoms 2020-06-03                 2
#                    6              AK Bottoms 2020-06-04                 1
# ...                                      ...        ...               ...
# Young boy Swimwear 8      Young boy Swimwear 2020-08-30                 1
#                    9      Young boy Swimwear 2020-09-01                 1
#                    9      Young boy Swimwear 2020-09-02                 1
#                    9      Young boy Swimwear 2020-09-07                 1
#                    9      Young boy Swimwear 2020-09-19                 2
#
#                           salesperdepartment  month
# department_name    month
# AK Bottoms         6                0.613203      6
#                    6                0.533763      6
#                    6                0.042356      6
#                    6                0.842407      6
#                    6                0.088932      6
# ...                                      ...    ...
# Young boy Swimwear 8                0.010153      8
#                    9                0.011847      9
#                    9                0.015237      9
#                    9                0.015237      9
#                    9                0.010153      9
#
# [41210 rows x 5 columns]

# %% [markdown]
# #### 5.1. Model Fit

# %%
#We impose a simple, linear, model:
# We specify salesperdepartment as the response variable (a.k.a dependent variable).

reg_re = plm.RandomEffects.from_formula(formula='salesperdepartment ~ C(month)+C(sales_channel_id)', data=SalesPerDepartment)

# %%
#We fit the model
results_re = reg_re.fit()
results_re
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:     salesperdepartment   R-squared:                        0.0507
# Estimator:              RandomEffects   R-squared (Between):             -0.0218
# No. Observations:               41210   R-squared (Within):               0.0513
# Date:                Wed, Aug 14 2024   R-squared (Overall):              0.0123
# Time:                        10:56:12   Log-likelihood                -1.354e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      549.84
# Entities:                         239   P-value                           0.0000
# Avg Obs:                       172.43   Distribution:                 F(4,41205)
# Min Obs:                       1.0000
# Max Obs:                       228.00   F-statistic (robust):             561.34
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(4,41205)
# Avg Obs:                     1.03e+04
# Min Obs:                       7780.0
# Max Obs:                    1.135e+04
#
#                                     Parameter Estimates
# ============================================================================================
#                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------------
# C(month)[T.6]                1.6515     0.4194     3.9379     0.0001      0.8295      2.4736
# C(month)[T.7]                0.5868     0.4194     1.3992     0.1618     -0.2352      1.4088
# C(month)[T.8]                0.6219     0.4197     1.4818     0.1384     -0.2007      1.4445
# C(month)[T.9]                1.0173     0.4217     2.4126     0.0158      0.1908      1.8438
# C(sales_channel_id)[T.2]     2.9149     0.0648     44.949     0.0000      2.7878      3.0420
# ============================================================================================
# RandomEffectsResults, id: 0x7e7e9995f610

# %% [markdown]
# #### 5.2. Model Interpretation
#
#
#
# #### The model explains up to 5% of the variance (R-squared=0.0507). This is probably too low to be considered an acceptable model in practice.
# #### The model is statistically significant (F-test: 549.84, p-value: 0.0000)
#
#
# #### Based on the above we conclude that:
#
# * sales have been decreasing accross time (-1.02, -0.88, -0.48)
#
# * sales in channel 2 are 2.9 units larger than sales in channel 1 (base reference)

# %% [markdown]
# ### 6. Random Effects or Fixed Effects ?
# #### We perform a Haussmann test to determine whether it makes any difference to use fixed or random effects models

# %%
## Let's fit a fixed effects model

reg_fe = plm.PanelOLS.from_formula(formula='salesperdepartment ~ C(month)+C(sales_channel_id)', data=SalesPerDepartment)

# %%
#We fit the model
results_fe = reg_fe.fit()
results_fe
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:     salesperdepartment   R-squared:                        0.0194
# Estimator:                   PanelOLS   R-squared (Between):             -0.0357
# No. Observations:               41210   R-squared (Within):               0.0507
# Date:                Wed, Aug 14 2024   R-squared (Overall):              0.0194
# Time:                        10:58:41   Log-likelihood                -1.521e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      203.92
# Entities:                         239   P-value                           0.0000
# Avg Obs:                       172.43   Distribution:                 F(4,41205)
# Min Obs:                       1.0000
# Max Obs:                       228.00   F-statistic (robust):             1141.6
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(4,41205)
# Avg Obs:                     1.03e+04
# Min Obs:                       7780.0
# Max Obs:                    1.135e+04
#
#                                     Parameter Estimates
# ============================================================================================
#                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------------
# C(month)[T.6]                2.5426     0.1043     24.379     0.0000      2.3382      2.7470
# C(month)[T.7]                1.5131     0.1034     14.636     0.0000      1.3105      1.7157
# C(month)[T.8]                1.6588     0.1051     15.785     0.0000      1.4528      1.8647
# C(month)[T.9]                2.0618     0.1211     17.032     0.0000      1.8245      2.2990
# C(sales_channel_id)[T.2]     2.6004     0.0956     27.213     0.0000      2.4131      2.7877
# ============================================================================================
#
#
# PanelEffectsResults, id: 0x7e7e999aa290

# %%
# Hausman test of FE vs. RE
# (I) find overlapping coefficients:
common_coef_set = set(results_fe.params.index).intersection(results_re.params.index)

common_coef_list=list(common_coef_set)
# (II) calculate differences between FE and RE:

b_re = results_re.params
b_re_cov = results_re.cov

b_fe = results_fe.params
b_fe_cov = results_fe.cov

# %%
common_coef_list
# Out:
# ['C(sales_channel_id)[T.2]',
#  'C(month)[T.7]',
#  'C(month)[T.8]',
#  'C(month)[T.6]',
#  'C(month)[T.9]']

# %%
b_diff = np.array(results_fe.params[common_coef_list] - results_re.params[common_coef_list])
df = len(b_diff)
b_diff.reshape((df, 1))
b_cov_diff = np.array(b_fe_cov.loc[common_coef_list, common_coef_list] -
                      b_re_cov.loc[common_coef_list, common_coef_list])
#b_cov_diff.reshape((df, df))


# (III) calculate test statistic:
stat = abs(np.transpose(b_diff) @ np.linalg.inv(b_cov_diff) @ b_diff)
pval = 1 - stats.chi2.cdf(stat, df)


print(f'stat: {stat}\n')
print(f'pval: {pval}\n')
# Out:
# stat: 19.572957225311548
#
# pval: 0.0015025524611191887

# %% [markdown]
# # How do we interpret the results?
#
# #### We have fit two alternative models: fixed-effects and random-effects.
#
# #### 1. Based on the results of the Hausman Test (19.57, p-value=0.0015) we are unable reject the hypotheses that both models are equivalent. We prefer the fixed effects model.
